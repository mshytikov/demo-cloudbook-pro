# %%
# %load_ext autoreload
# %autoreload 2

# %%
from cabby import create_client
from cabby.cli import collections

# %%
from types import SimpleNamespace

# %%
args = SimpleNamespace(as_xml=False)

path ="http://opentaxii2/services/collection-management-a"


client = create_client()

client.set_auth(
    cert_file=None,
    key_file=None,
    username=None,
    password=None,
    key_password=None,
    jwt_auth_url=None,
    verify_ssl=False
)


collections._runner(client, path, args)
# Out:
# === Data Collection Information ===
#   Collection Name: collection-a
#   Collection Type: DATA_SET
#   Available: True
#   Collection Description: None
#   Supported Content: All
#   === Polling Service Instance ===
#     Poll Protocol: urn:taxii.mitre.org:protocol:http:1.0
#     Poll Address: http://192.168.59.103/services/poll-a
#     Message Binding: urn:taxii.mitre.org:message:xml:1.0
#     Message Binding: urn:taxii.mitre.org:message:xml:1.1
#   === Subscription Service ===
#     Protocol Binding: urn:taxii.mitre.org:protocol:http:1.0
#     Address: http://192.168.59.103/services/collection-management-a
#     Message Binding: urn:taxii.mitre.org:message:xml:1.0
#     Message Binding: urn:taxii.mitre.org:message:xml:1.1
#   === Subscription Service ===
#     Protocol Binding: urn:taxii.mitre.org:protocol:https:1.0
#     Address: https://192.168.59.103/services/collection-management-a
#     Message Binding: urn:taxii.mitre.org:message:xml:1.0
# ...
